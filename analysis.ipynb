# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
result_moss = pd.read_csv("results/results_MoSS.csv")
result_moss_mn = pd.read_csv("results/results_MoSS_MN.csv")
result_moss_dir = pd.read_csv("results/results_MoSS_Dir.csv")
results = pd.concat([result_moss, result_moss_mn, result_moss_dir], axis=0)
results.head()
# Out:
#   Quantifier MoSS Variant Test MoSS Variant Train  m_proximity       MAE  \
# 0        DyS              MoSS           MoSS_Dir          0.0  0.000822
# 1        DyS              MoSS           MoSS_Dir          0.0  0.002028
# 2        DyS              MoSS           MoSS_Dir          0.0  0.001578
# 3        DyS              MoSS           MoSS_Dir          0.0  0.000706
# 4        DyS              MoSS           MoSS_Dir          0.0  0.001935
#
#    m_test  alpha
# 0     0.1    0.1
# 1     0.1    0.2
# 2     0.1    0.4
# 3     0.1    0.6
# 4     0.1    0.8

# %%
fig = px.box(results, x="MoSS Variant Test", y="m_proximity", color="MoSS Variant Test")
fig.show()

# %%
fig = px.box(results, x="MoSS Variant Test", y="m_proximity", color="MoSS Variant Train")
fig.show()

# %%
fig = px.box(results, x="MoSS Variant Test", y="MAE", color="MoSS Variant Train")
fig.show()
